# %%
import folium
from function import folium_functions

global_path = '../data/London_in_depth/'
output_map_name = global_path + "london_venues.html"

# %% [markdown]
# # Load data

# %%
# Files containing the position of the London underground stations and lines
filename_venues = global_path + 'london_venues.csv'

# %% [markdown]
# # Initialize the map

# %%
city_of_london_coordinates = [51.51279, -0.09184]
m = folium.Map(location=city_of_london_coordinates, zoom_start=12)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# # Add the venues

# %%
dic_venues = folium_functions.pipeline_venues(filename_venues, current_map=m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
